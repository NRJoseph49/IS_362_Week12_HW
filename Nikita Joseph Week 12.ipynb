# %% [markdown]
# # Creating a Dataframe from an API

# %%
import pandas as pd
import requests
import json

#api key
api_key = "S8zHEEG45YRfqFuF9SEuVmsvniB9lhtO"
# resource url
url = "https://api.nytimes.com/svc/archive/v1/2012/2.json?&query=smoking&api-key= " + api_key
r = requests.get(url)

# get json
request_data= r.json()
# filter to get required data
data=request_data['response']['docs']

# create a dataframe
df = pd.DataFrame(data)
df.head()
# Out:
#                                              web_url  \
# 0  https://thequad.blogs.nytimes.com/2012/02/01/c...
# 1  https://thequad.blogs.nytimes.com/2012/02/01/c...
# 2  https://thelede.blogs.nytimes.com/2012/02/01/k...
# 3  https://thelede.blogs.nytimes.com/2012/02/01/k...
# 4  https://fifthdown.blogs.nytimes.com/2012/02/01...
#
#                                              snippet  \
# 0  Two teams affected by N.C.A.A. probes, Ohio St...
# 1  Two teams affected by N.C.A.A. probes, Ohio St...
# 2  Upset over the decision by Susan G. Komen for ...
# 3  Upset over the decision by Susan G. Komen for ...
# 4  The Patriots dominated offensively with Rob Gr...
#
#                                       lead_paragraph  \
# 0                                               None
# 1  National signing day has turned into a made-fo...
# 2                                               None
# 3  In the last 24 hours, thousands of women turne...
# ...
